# %%
import os

# %%
from syslog_processing import Processing

# %%
obj = Processing()

# %%
input_csv_name = "GPN_Syslog_10000.csv"
input_dir = "data"
input_csv_path = os.path.join(input_dir,input_csv_name)

# %%
desc = obj.get_all_descriptions(input_csv_path= input_csv_path)

# %%
print(desc)
# Out:
# ['ospf router id conflict is detected on the interface.', 'the source ip was unlocked.', 'the ip address of request message was unlocked because timeout.', '', '', '', '', 'succeeded in establishing the ops connection.', 'ops operation information.', '', 'log snmp/snmp_authen_failed is suppressed 2 in last 60 seconds.', 'log snmp/authenticationfailure is suppressed 2 in last 60 seconds.', 'failed to login through snmp.', '', 'the user had a request.', 'last message repeated 5 times.', 'the user had a request.', 'the ssh user failed to login.', 'log snmp/authenticationfailure is suppressed 2 in last 60 seconds.', 'log snmp/snmp_authen_failed is suppressed 2 in last 60 seconds.', 'auto port-defend stop.', 'ops operation information.', 'ops operation information.', 'the ops connection was disconnected.', 'in the last 5 minutes, 3 ip addresses were unlocked.', 'in the last 5 minutes, 3 ip addresses were locked.', 'ssh connect was closed.', 'the user had a request.', 'failed to login through snmp.', '', 'last message repeated 2 times.', '', 'the ip address of request message was locked because authentication failed.', 'the user had a request.', '', 'the source ip was locked because of the failure of login through snmp.', 'failed to login through snmp.', 'the user had a request.', 'last message repeated 1 times.', 'the user had a request.', 'the user had a request.', '', '', 'the ssh user failed to login.', 'last message repeated 3 times.', 'the ssh user failed to login.', 'ospf router id conflict is detected on the interface.', 'the ssh user failed to login.', 'the ssh user failed to login.', 'the source ip was unlocked.', 'the ssh user failed to login.', 'the ssh user failed to login.', '', 'last message repeated 2 times.', 'the user had a request.', 'log snmp/snmp_authen_failed is suppressed 1 in last 60 seconds.', 'log snmp/authenticationfailure is suppressed 1 in last 60 seconds.', '', 'failed to login through ssh 17 time', 'auto port-defend stop.', '', '', 'the state of the peer changed after receiving an event.', '', 'the user had a request.', 'ip was unlocked.', 'the source ip was locked because of the failure of login through snmp.', 'failed to login through snmp.', 'the ssh user failed to login.', 'the ssh user failed to login.', 'last message repeated 1 times.', 'the user had a request.', 'last message repeated 3 times.', '', '', 'ospf router id conflict is detected on the interface.', 'the ssh user failed to login.', 'the user had a request.', 'last message repeated 2 times.', 'failed to login through snmp.', '', '', 'failed to login through ssh 3 time', 'the ssh user failed to login.', '', '', 'succeeded in establishing the ops connection.', 'ops operation information.', '', '', 'ops operation information.', 'ops operation information.', 'the ops connection was disconnected.', '', '', 'the user had a request.', 'last message repeated 4 times.', 'the user had a request.', 'ssh connect was closed.', '', '', '', 'the ssh user failed to login.', 'auto port-defend stop.', 'failed to login through ssh 7 time', 'automatic record:', 'automatic record:', 'automatic record:', 'automatic record:', 'the user had a request.', 'the user had a request.', 'the user failed to log in to vty0.', 'automatic record:', 'automatic record:', 'automatic record:', 'automatic record:', 'component plug in or plug out information.', 'component plug in or plug out information.', 'the ssh user failed to login.', 'the ssh user failed to login.', 'last message repeated 3 times.', '', 'component plug in or plug out information.', 'component plug in or plug out information.', 'the ssh user failed to login.', '', '', '', 'failed to login through snmp.', 'the source ip was locked because of the failure of login through snmp.', 'failed to login through snmp.', 'component plug in or plug out information.', 'last message repeated 5 times.', 'component plug in or plug out information.', 'the ssh user failed to login.', 'component plug in or plug out informatio ...

# %%
print(len(desc))
# Out:
# 10000
